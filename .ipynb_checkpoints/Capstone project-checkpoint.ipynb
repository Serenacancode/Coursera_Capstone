# %% [markdown]
# # Capstone Project Summary

# %% [markdown]
# 2020-08-14

# %% [markdown]
# ## 1. Introduction/Business Problem
#
# ### 1.1 Discover which neighborhood in Melhourne is the best for young families
#
# <br>
#
# Melbourne, one of the most populous cities in Australia, attracted nearly 1 million people to move into since 2001.
#
# Lots of newcomers to Melbourne are highly interested in what the city has to offer, and especially what venues and facilities are in each neighborhood.
# Without having enough information on each neighborhood, it would be a difficult problem for them to decide where to live.
#
# So this project is here for those people with young family who are looking to move into Melbourne and want to find out the neighborhood that fit them the best. The project will help the target audiences by providing the relevant information on each neighborhood visually on the map. The project will analysis each neighborhood on the venues and facilities it has, with main focus on the ease of accessing grocery stores, school, drug stores, cafes, malls, hospitals, etc, all of which are accessible from Foursquare location data.

# %% [markdown]
# ### 1.2  Target Audience
#
# 1. Business professional around the world who wants to move into Melbourne. This analysis will be a comprehensive guide to choose where to live in Melbourne
#
# 2. Local residents in Melbourne who wish to get to know their city better.
#
# 3. Travellers, freelancers, bloggers, and influencers who wants to get to know the City of Melbourne for their next vacation.
#
# 4. Data scientists, who wish to analyze the neighborhoods of Melbourne using Exploratory Data Analysis and other statistical & machine learning techniques to obtain all the necessary data, perform some operations on it and, tell a story out of it.

# %% [markdown]
# ## 2. Data
#
# ### 2.1 Data Sources
#
# Foursquare API (https://developer.foursquare.com/docs) will be used to obtain information for each venue:
#
#     - Name: The name of the venue.
#     - Category: The category type as defined by the API.
#     - Latitude: The latitude value of the venue.
#     - Longitude: The longitude value of the venue.
#
#
# From this website (https://www.geonames.org/postal-codes/AU/VIC/victoria.html), I was able to retrieve the following for entire victoria:
#
#     - Place: name of the neighborhood
#     - Code: postal code
#     - Country: country of the postal code
#     - Admin1: province
#     - Admin2: city name
#     - Admin3: additional information
#
# From this website (https://en.wikipedia.org/wiki/List_of_Melbourne_suburbs), I was able to extract the list of suburbs with the corresponding city municipalities
#
#     - City municipalition
#     - Suburbs names
#     - Postal code

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
# Out:
# Solving environment: \ ^C
# failed
#
# CondaError: KeyboardInterrupt
#
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_1        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'ST4O01JM33Z0IGCYAXNREQKWZYKF4AD4UMV0NBO4II4AUQ2T' # your Foursquare ID
CLIENT_SECRET = 'RZQ3S4HAHXB4VOXWE4GAYKWZ11IAFOHRGGT5QOUSQZO4ZE3K' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ST4O01JM33Z0IGCYAXNREQKWZYKF4AD4UMV0NBO4II4AUQ2T
# CLIENT_SECRET:RZQ3S4HAHXB4VOXWE4GAYKWZ11IAFOHRGGT5QOUSQZO4ZE3K

# %%
address = 'melbourne, Australia'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

search_query = 'Geocery store'
radius = 500
# Out:
# -37.8142176 144.9631608

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f36b7cd7ce56f2a2f4a4406'},
#  'response': {'venues': [{'id': '514950b2e4b03b3a7d5568e0',
#     'name': 'Rivers Clearance Store',
#     'location': {'address': 'Elizabeth St.',
#      'lat': -37.81412108862014,
#      'lng': 144.9633534929965,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81412108862014,
#        'lng': 144.9633534929965}],
#      'distance': 20,
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Elizabeth St.', 'Melbourne VIC', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4ff3e487e4b0734a79435b5c',
#     'name': 'Telstra Store',
#     'location': {'address': '156 Elizabeth Street',
#      'lat': -37.8142137,
#      'lng': 144.9637776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.8142137,
#        'lng': 144.9637776}],
#      'distance': 54,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['156 Elizabeth Street',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '556532197'},
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '5c37f507f1fdaf002c76eaf6',
#     'name': 'Galleria Express Grocery Store',
#     'location': {'address': '385 Bourke St',
#      'crossStreet': 'Elizabeth/Bourke St',
#      'lat': -37.81478,
#      'lng': 144.96278,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81478,
#        'lng': 144.96278}],
#      'distance': 70,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['385 Bourke St (Elizabeth/Bourke St)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4b058751f964a520878b22e3',
#     'name': "David Jones - Men's Store",
#     'location': {'address': '299-307 Bourke St',
#      'crossStreet': 'Btwn Little Collins St & Bourke St',
#      'lat': -37.813907005911574,
#      'lng': 144.9646174513385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.813907005911574,
#        'lng': 144.9646174513385}],
#      'distance': 132,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['299-307 Bourke St (Btwn Little Collins St & Bourke St)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'shortName': 'Department Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4bcfd773caff9521bbfecdf0',
#     'name': 'City Convenience Store',
#     'location': {'address': '190 Queen Street,',
#      'crossStreet': 'Little Bourke Street',
#      'lat': -37.813849195491834,
#      'lng': 144.9602236621532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.813849195491834,
#        'lng': 144.9602236621532}],
#      'distance': 261,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['190 Queen Street, (Little Bourke Street)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4b3ff1a4f964a520aab225e3',
#     'name': 'Camper',
#     'location': {'address': 'Shop G046 Emporium, 287 Lonsdale St, Melbourne - VIC',
#      'lat': -37.81370838514021,
#      'lng': 144.96327996253967,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81370838514021,
#        'lng': 144.96327996253967}],
#      'distance': 57,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Shop G046 Emporium, 287 Lonsdale St, Melbourne - VIC',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d107951735',
#       'name': 'Shoe Store',
#       'pluralName': 'Shoe Stores',
#       'shortName': 'Shoes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4b359502f964a520fe2d25e3',
#     'name': 'Hello Kitty Store (Sanrio)',
#     'location': {'address': 'Shop 39 246 Bourke Street',
#      'crossStreet': 'Swanston St.',
#      'lat': -37.81331269090593,
#      'lng': 144.9653755762427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81331269090593,
#        'lng': 144.9653755762427}],
#      'distance': 219,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 39 246 Bourke Street (Swanston St.)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1f3941735',
#       'name': 'Toy / Game Store',
#       'pluralName': 'Toy / Game Stores',
#       'shortName': 'Toys & Games',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/toys_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4ceb51feb997548167220c45',
#     'name': "David Jones - Women's Store",
#     'location': {'address': '310 Bourke St',
#      'crossStreet': 'Btwn Bourke St & Little Bourke St',
#      'lat': -37.81339880479703,
#      'lng': 144.9644166298955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81339880479703,
#        'lng': 144.9644166298955}],
#      'distance': 143,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['310 Bourke St (Btwn Bourke St & Little Bourke St)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'shortName': 'Department Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '53636bfc498ed129442a87b9',
#     'name': 'Bose Store',
#     'location': {'lat': -37.81233656616666,
#      'lng': 144.96357936158515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81233656616666,
#        'lng': 144.96357936158515}],
#      'distance': 212,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1fe941735',
#       'name': 'Music Store',
#       'pluralName': 'Music Stores',
#       'shortName': 'Music Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/music_instruments_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '546ebeec498ea5bc4ea7dca3',
#     'name': 'The Tumi Store',
#     'location': {'address': 'Emporium Melbourne',
#      'crossStreet': 'G041, 295 Lonsdale Street',
#      'lat': -37.81498122199882,
#      'lng': 144.9636116285759,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81498122199882,
#        'lng': 144.9636116285759}],
#      'distance': 93,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Emporium Melbourne (G041, 295 Lonsdale Street)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b29',
#       'name': 'Luggage Store',
#       'pluralName': 'Luggage Stores',
#       'shortName': 'Luggage Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '51d920f8498e0f9996ab86f2',
#     'name': 'P!NK POP-UP Store',
#     'location': {'address': '£1000 Bend',
#      'crossStreet': '361 Little Lonsdale St.',
#      'lat': -37.811785901139544,
#      'lng': 144.96189073968165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.811785901139544,
#        'lng': 144.96189073968165}],
#      'distance': 292,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['£1000 Bend (361 Little Lonsdale St.)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4ba57bf4f964a520a80b39e3',
#     'name': 'That Store',
#     'location': {'address': 'GD59 Melbourne Central, 211 La Trobe St',
#      'lat': -37.81112319951579,
#      'lng': 144.96376276016235,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81112319951579,
#        'lng': 144.96376276016235}],
#      'distance': 348,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['GD59 Melbourne Central, 211 La Trobe St',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4b2aeadef964a52010b224e3',
#     'name': 'Telstra Store',
#     'location': {'address': '246-260 Bourke Street',
#      'crossStreet': 'at Swanston St.',
#      'lat': -37.81323039999999,
#      'lng': 144.965941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81323039999999,
#        'lng': 144.965941}],
#      'distance': 268,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['246-260 Bourke Street (at Swanston St.)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#       'name': 'Mobile Phone Shop',
#       'pluralName': 'Mobile Phone Shops',
#       'shortName': 'Mobile Phones',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '552031402'},
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '523fd85f498e44a9f50274f9',
#     'name': 'Illamasqua Makeup Store',
#     'location': {'address': 'Myer Bourke Street',
#      'lat': -37.81522455781199,
#      'lng': 144.96405798988505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81522455781199,
#        'lng': 144.96405798988505}],
#      'distance': 137,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Myer Bourke Street',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d10c951735',
#       'name': 'Cosmetics Shop',
#       'pluralName': 'Cosmetics Shops',
#       'shortName': 'Cosmetics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '51d4de38498ee6c485700bcb',
#     'name': 'My Adventure Store',
#     'location': {'lat': -37.813517,
#      'lng': 144.961628,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.813517,
#        'lng': 144.961628}],
#      'distance': 155,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1f6931735',
#       'name': 'General Travel',
#       'pluralName': 'General Travel',
#       'shortName': 'Travel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4ee411945c5cfa48fa1fa0b3',
#     'name': "Levi's Store",
#     'location': {'address': 'Melbourne Central',
#      'lat': -37.81041496930415,
#      'lng': 144.96331584829073,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81041496930415,
#        'lng': 144.96331584829073}],
#      'distance': 423,
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Melbourne Central', 'Melbourne VIC', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4b4005aaf964a5205fb425e3',
#     'name': 'Somewhere Store',
#     'location': {'address': '314 Little Collins St.',
#      'crossStreet': 'Level 2, Royal Arcade',
#      'lat': -37.81494666120684,
#      'lng': 144.96420134845368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81494666120684,
#        'lng': 144.96420134845368}],
#      'distance': 122,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['314 Little Collins St. (Level 2, Royal Arcade)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '5b895204286fda002cad42bf',
#     'name': 'Cranbourne Music Melbourne Store',
#     'location': {'address': '105 Elizabeth St',
#      'lat': -37.815775,
#      'lng': 144.963567,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.815775,
#        'lng': 144.963567}],
#      'distance': 177,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['105 Elizabeth St',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1fe941735',
#       'name': 'Music Store',
#       'pluralName': 'Music Stores',
#       'shortName': 'Music Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/music_instruments_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '535b3da7498e1c1f30c7f617',
#     'name': 'The Metropolitan Museum of Art Store',
#     'location': {'address': 'Level 3, Melbourne Emporium',
#      'lat': -37.8126908145265,
#      'lng': 144.9638374978579,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.8126908145265,
#        'lng': 144.9638374978579}],
#      'distance': 180,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Level 3, Melbourne Emporium', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '5bd680e52632ec002c350b5f',
#     'name': 'Someday Store',
#     'location': {'lat': -37.812668,
#      'lng': 144.964182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.812668,
#        'lng': 144.964182}],
#      'distance': 194,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Melbourne VIC 3000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d102951735',
#       'name': 'Accessories Store',
#       'pluralName': 'Accessories Stores',
#       'shortName': 'Accessories',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '5c7cd399180b910039710dca',
#     'name': 'Leica Store & Gallery',
#     'location': {'address': '260 Collins St',
#      'lat': -37.8153239,
#      'lng': 144.96493,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.8153239,
#        'lng': 144.96493}],
#      'distance': 198,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['260 Collins St',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4eb1bdf03b7b55596b4a7491',
#       'name': 'Camera Store',
#       'pluralName': 'Camera Stores',
#       'shortName': 'Camera Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/camerastore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '5c5142c9898bdc002ca1e708',
#     'name': 'PR Cool Stores',
#     'location': {'address': '5 Haveaux Street',
#      'lat': -37.815208598896234,
#      'lng': 144.96374130249023,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.815208598896234,
#        'lng': 144.96374130249023}],
#      'distance': 121,
#      'postalCode': '3030',
#      'cc': 'AU',
#      'city': 'Werribee',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['5 Haveaux Street',
#       'Werribee VIC 3030',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d102951735',
#       'name': 'Accessories Store',
#       'pluralName': 'Accessories Stores',
#       'shortName': 'Accessories',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '54990151498e4a0dda00303f',
#     'name': 'Verner Store',
#     'location': {'address': 'level 1, 358 Lonsdale St',
#      'lat': -37.81227049030436,
#      'lng': 144.96214887077048,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81227049030436,
#        'lng': 144.96214887077048}],
#      'distance': 234,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['level 1, 358 Lonsdale St',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4bac048df964a52068de3ae3',
#     'name': 'i-store Computers',
#     'location': {'address': '388 Lonsdale St',
#      'lat': -37.81362111794614,
#      'lng': 144.95969127984216,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81362111794614,
#        'lng': 144.95969127984216}],
#      'distance': 312,
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['388 Lonsdale St', 'Melbourne VIC', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d122951735',
#       'name': 'Electronics Store',
#       'pluralName': 'Electronics Stores',
#       'shortName': 'Electronics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4db3c1c493a017099dcbb2bd',
#     'name': 'The Metropolitan Museum Of Art Store',
#     'location': {'lat': -37.815426216162074,
#      'lng': 144.9649829871281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.815426216162074,
#        'lng': 144.9649829871281}],
#      'distance': 209,
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Melbourne VIC', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4dec6dc37d8b6c7a5371f5d4',
#     'name': 'Health Store',
#     'location': {'address': '255 Elizabeth Street',
#      'crossStreet': 'Lonsdale St. & Little Bourke St.',
#      'lat': -37.81275,
#      'lng': 144.96219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81275,
#        'lng': 144.96219}],
#      'distance': 184,
#      'postalCode': '3000',
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['255 Elizabeth Street (Lonsdale St. & Little Bourke St.)',
#       'Melbourne VIC 3000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '534dbaef498e1cf349e09668',
#     'name': 'Neverland',
#     'location': {'address': '297 Lonsdale St',
#      'lat': -37.81278469594145,
#      'lng': 144.96410639065132,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.81278469594145,
#        'lng': 144.96410639065132}],
#      'distance': 179,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['297 Lonsdale St', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4b5d3fcaf964a520bb5729e3',
#     'name': 'Whatever Store',
#     'location': {'address': 'Melbourne Central',
#      'crossStreet': 'Lonsdale St',
#      'lat': -37.811759,
#      'lng': 144.963672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.811759,
#        'lng': 144.963672}],
#      'distance': 277,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Melbourne Central (Lonsdale St)', 'Australia']},
#     'categories': [],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4ddf8027b0fbefa198c605b5',
#     'name': 'Caffetteria Food Store',
#     'location': {'lat': -37.814062,
#      'lng': 144.95997,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.814062,
#        'lng': 144.95997}],
#      'distance': 281,
#      'cc': 'AU',
#      'city': 'Melbourne',
#      'state': 'VIC',
#      'country': 'Australia',
#      'formattedAddress': ['Melbourne VIC', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False},
#    {'id': '4fa8e308e4b0bad895373a50',
#     'name': 'C-Store',
#     'location': {'address': 'Swanston Street',
#      'lat': -37.816028,
#      'lng': 144.967484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -37.816028,
#        'lng': 144.967484}],
#      'distance': 430,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Swanston Street', 'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597422023',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
# venues = results['response']['venues']
venues = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d1ff941735', 'name': 'M...    False
# 2  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 4  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...    False
#
#                          id      location.address location.cc location.city  \
# 0  514950b2e4b03b3a7d5568e0         Elizabeth St.          AU     Melbourne
# 1  4ff3e487e4b0734a79435b5c  156 Elizabeth Street          AU     Melbourne
# 2  5c37f507f1fdaf002c76eaf6         385 Bourke St          AU     Melbourne
# 3  4b058751f964a520878b22e3     299-307 Bourke St          AU     Melbourne
# 4  4bcfd773caff9521bbfecdf0     190 Queen Street,          AU     Melbourne
#
#   location.country                location.crossStreet  location.distance  \
# 0        Australia                                 NaN                 20
# 1        Australia                                 NaN                 54
# 2        Australia                 Elizabeth/Bourke St                 70
# 3        Australia  Btwn Little Collins St & Bourke St                132
# 4        Australia                Little Bourke Street                261
#
#                            location.formattedAddress  \
# 0          [Elizabeth St., Melbourne VIC, Australia]
# 1  [156 Elizabeth Street, Melbourne VIC 3000, Aus...
# 2  [385 Bourke St (Elizabeth/Bourke St), Melbourn...
# 3  [299-307 Bourke St (Btwn Little Collins St & B...
# 4  [190 Queen Street, (Little Bourke Street), Mel...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -37.8141210886201...    -37.814121
# 1  [{'label': 'display', 'lat': -37.8142137, 'lng...    -37.814214
# 2  [{'label': 'display', 'lat': -37.81478, 'lng':...    -37.814780
# 3  [{'label': 'display', 'lat': -37.8139070059115...    -37.813907
# 4  [{'label': 'display', 'lat': -37.8138491954918...    -37.813849
#
#    location.lng location.postalCode location.state  \
# 0    144.963353                 NaN            VIC
# 1    144.963778                3000            VIC
# 2    144.962780                3000            VIC
# 3    144.964617                3000            VIC
# 4    144.960224                3000            VIC
#
#                              name    referralId venuePage.id
# 0          Rivers Clearance Store  v-1597422023          NaN
# 1                   Telstra Store  v-1597422023    556532197
# 2  Galleria Express Grocery Store  v-1597422023          NaN
# 3       David Jones - Men's Store  v-1597422023          NaN
# 4          City Convenience Store  v-1597422023          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                     name          categories  \
# 0                 Rivers Clearance Store      Clothing Store
# 1                          Telstra Store  Miscellaneous Shop
# 2         Galleria Express Grocery Store       Grocery Store
# 3              David Jones - Men's Store    Department Store
# 4                 City Convenience Store   Convenience Store
# 5                                 Camper          Shoe Store
# 6             Hello Kitty Store (Sanrio)    Toy / Game Store
# 7            David Jones - Women's Store    Department Store
# 8                             Bose Store         Music Store
# 9                         The Tumi Store       Luggage Store
# 10                     P!NK POP-UP Store            Boutique
# 11                            That Store            Boutique
# 12                         Telstra Store   Mobile Phone Shop
# 13               Illamasqua Makeup Store      Cosmetics Shop
# 14                    My Adventure Store      General Travel
# 15                          Levi's Store            Boutique
# 16                       Somewhere Store            Boutique
# 17      Cranbourne Music Melbourne Store         Music Store
# 18  The Metropolitan Museum of Art Store           Gift Shop
# 19                         Someday Store   Accessories Store
# 20                 Leica Store & Gallery        Camera Store
# 21                        PR Cool Stores   Accessories Store
# 22                          Verner Store      Clothing Store
# 23                     i-store Computers   Electronics Store
# 24  The Metropolitan Museum Of Art Store         Art Gallery
# 25                          Health Store            Pharmacy
# 26                             Neverland            Boutique
# 27                        Whatever Store                None
# 28                Caffetteria Food Store                 Bar
# 29                               C-Store   Convenience Store
#
#                                               address  cc       city  \
# 0                                       Elizabeth St.  AU  Melbourne
# 1                                156 Elizabeth Street  AU  Melbourne
# 2                                       385 Bourke St  AU  Melbourne
# 3                                   299-307 Bourke St  AU  Melbourne
# 4                                   190 Queen Street,  AU  Melbourne
# 5   Shop G046 Emporium, 287 Lonsdale St, Melbourne...  AU  Melbourne
# 6                           Shop 39 246 Bourke Street  AU  Melbourne
# 7                                       310 Bourke St  AU  Melbourne
# 8                                                 NaN  AU        NaN
# 9                                  Emporium Melbourne  AU  Melbourne
# 10                                         £1000 Bend  AU  Melbourne
# 11            GD59 Melbourne Central, 211 La Trobe St  AU  Melbourne
# 12                              246-260 Bourke Street  AU  Melbourne
# 13                                 Myer Bourke Street  AU  Melbourne
# 14                                                NaN  AU        NaN
# 15                                  Melbourne Central  AU  Melbourne
# 16                             314 Little Collins St.  AU  Melbourne
# 17                                   105 Elizabeth St  AU  Melbourne
# 18                        Level 3, Melbourne Emporium  AU        NaN
# 19                                                NaN  AU  Melbourne
# 20                                     260 Collins St  AU  Melbourne
# 21                                   5 Haveaux Street  AU   Werribee
# 22                           level 1, 358 Lonsdale St  AU  Melbourne
# 23                                    388 Lonsdale St  AU  Melbourne
# 24                                                NaN  AU  Melbourne
# 25                               255 Elizabeth Street  AU  Melbourne
# 26                                    297 Lonsdale St  AU        NaN
# 27                                  Melbourne Central  AU        NaN
# 28                                                NaN  AU  Melbourne
# 29                                    Swanston Street  AU        NaN
#
#       country                         crossStreet  distance  \
# 0   Australia                                 NaN        20
# 1   Australia                                 NaN        54
# 2   Australia                 Elizabeth/Bourke St        70
# 3   Australia  Btwn Little Collins St & Bourke St       132
# 4   Australia                Little Bourke Street       261
# 5   Australia                                 NaN        57
# 6   Australia                        Swanston St.       219
# 7   Australia   Btwn Bourke St & Little Bourke St       143
# 8   Australia                                 NaN       212
# 9   Australia           G041, 295 Lonsdale Street        93
# 10  Australia             361 Little Lonsdale St.       292
# 11  Australia                                 NaN       348
# 12  Australia                     at Swanston St.       268
# 13  Australia                                 NaN       137
# 14  Australia                                 NaN       155
# 15  Australia                                 NaN       423
# 16  Australia               Level 2, Royal Arcade       122
# 17  Australia                                 NaN       177
# 18  Australia                                 NaN       180
# 19  Australia                                 NaN       194
# 20  Australia                                 NaN       198
# 21  Australia                                 NaN       121
# 22  Australia                                 NaN       234
# 23  Australia                                 NaN       312
# 24  Australia                                 NaN       209
# 25  Australia    Lonsdale St. & Little Bourke St.       184
# 26  Australia                                 NaN       179
# 27  Australia                         Lonsdale St       277
# 28  Australia                                 NaN       281
# 29  Australia                                 NaN       430
#
#                                      formattedAddress  \
# 0           [Elizabeth St., Melbourne VIC, Australia]
# 1   [156 Elizabeth Street, Melbourne VIC 3000, Aus...
# 2   [385 Bourke St (Elizabeth/Bourke St), Melbourn...
# 3   [299-307 Bourke St (Btwn Little Collins St & B...
# 4   [190 Queen Street, (Little Bourke Street), Mel...
# 5   [Shop G046 Emporium, 287 Lonsdale St, Melbourn...
# 6   [Shop 39 246 Bourke Street (Swanston St.), Mel...
# 7   [310 Bourke St (Btwn Bourke St & Little Bourke...
# 8                                         [Australia]
# 9   [Emporium Melbourne (G041, 295 Lonsdale Street...
# 10  [£1000 Bend (361 Little Lonsdale St.), Melbour...
# 11  [GD59 Melbourne Central, 211 La Trobe St, Melb...
# 12  [246-260 Bourke Street (at Swanston St.), Melb...
# 13  [Myer Bourke Street, Melbourne VIC 3000, Austr...
# 14                                        [Australia]
# 15      [Melbourne Central, Melbourne VIC, Australia]
# 16  [314 Little Collins St. (Level 2, Royal Arcade...
# 17  [105 Elizabeth St, Melbourne VIC 3000, Australia]
# 18           [Level 3, Melbourne Emporium, Australia]
# 19                    [Melbourne VIC 3000, Australia]
# 20    [260 Collins St, Melbourne VIC 3000, Australia]
# 21   [5 Haveaux Street, Werribee VIC 3030, Australia]
# 22  [level 1, 358 Lonsdale St, Melbourne VIC 3000,...
# 23        [388 Lonsdale St, Melbourne VIC, Australia]
# 24                         [Melbourne VIC, Australia]
# 25  [255 Elizabeth Street (Lonsdale St. & Little B...
# 26                       [297 Lonsdale St, Australia]
# 27       [Melbourne Central (Lonsdale St), Australia]
# 28                         [Melbourne VIC, Australia]
# 29                       [Swanston Street, Australia]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'label': 'display', 'lat': -37.8141210886201... -37.814121  144.963353
# 1   [{'label': 'display', 'lat': -37.8142137, 'lng... -37.814214  144.963778
# 2   [{'label': 'display', 'lat': -37.81478, 'lng':... -37.814780  144.962780
# 3   [{'label': 'display', 'lat': -37.8139070059115... -37.813907  144.964617
# 4   [{'label': 'display', 'lat': -37.8138491954918... -37.813849  144.960224
# 5   [{'label': 'display', 'lat': -37.8137083851402... -37.813708  144.963280
# 6   [{'label': 'display', 'lat': -37.8133126909059... -37.813313  144.965376
# 7   [{'label': 'display', 'lat': -37.8133988047970... -37.813399  144.964417
# 8   [{'label': 'display', 'lat': -37.8123365661666... -37.812337  144.963579
# 9   [{'label': 'display', 'lat': -37.8149812219988... -37.814981  144.963612
# 10  [{'label': 'display', 'lat': -37.8117859011395... -37.811786  144.961891
# 11  [{'label': 'display', 'lat': -37.8111231995157... -37.811123  144.963763
# 12  [{'label': 'display', 'lat': -37.8132303999999... -37.813230  144.965941
# 13  [{'label': 'display', 'lat': -37.8152245578119... -37.815225  144.964058
# 14  [{'label': 'display', 'lat': -37.813517, 'lng'... -37.813517  144.961628
# 15  [{'label': 'display', 'lat': -37.8104149693041... -37.810415  144.963316
# 16  [{'label': 'display', 'lat': -37.8149466612068... -37.814947  144.964201
# 17  [{'label': 'display', 'lat': -37.815775, 'lng'... -37.815775  144.963567
# 18  [{'label': 'display', 'lat': -37.8126908145265... -37.812691  144.963837
# 19  [{'label': 'display', 'lat': -37.812668, 'lng'... -37.812668  144.964182
# 20  [{'label': 'display', 'lat': -37.8153239, 'lng... -37.815324  144.964930
# 21  [{'label': 'display', 'lat': -37.8152085988962... -37.815209  144.963741
# 22  [{'label': 'display', 'lat': -37.8122704903043... -37.812270  144.962149
# 23  [{'label': 'display', 'lat': -37.8136211179461... -37.813621  144.959691
# 24  [{'label': 'display', 'lat': -37.8154262161620... -37.815426  144.964983
# 25  [{'label': 'display', 'lat': -37.81275, 'lng':... -37.812750  144.962190
# 26  [{'label': 'display', 'lat': -37.8127846959414... -37.812785  144.964106
# 27  [{'label': 'display', 'lat': -37.811759, 'lng'... -37.811759  144.963672
# 28  [{'label': 'display', 'lat': -37.814062, 'lng'... -37.814062  144.959970
# 29  [{'label': 'display', 'lat': -37.816028, 'lng'... -37.816028  144.967484
#
#    postalCode state                        id
# 0         NaN   VIC  514950b2e4b03b3a7d5568e0
# 1        3000   VIC  4ff3e487e4b0734a79435b5c
# 2        3000   VIC  5c37f507f1fdaf002c76eaf6
# 3        3000   VIC  4b058751f964a520878b22e3
# 4        3000   VIC  4bcfd773caff9521bbfecdf0
# 5        3000   VIC  4b3ff1a4f964a520aab225e3
# 6        3000   VIC  4b359502f964a520fe2d25e3
# 7        3000   VIC  4ceb51feb997548167220c45
# 8         NaN   NaN  53636bfc498ed129442a87b9
# 9        3000   VIC  546ebeec498ea5bc4ea7dca3
# 10       3000   VIC  51d920f8498e0f9996ab86f2
# 11       3000   VIC  4ba57bf4f964a520a80b39e3
# 12       3000   VIC  4b2aeadef964a52010b224e3
# 13       3000   VIC  523fd85f498e44a9f50274f9
# 14        NaN   NaN  51d4de38498ee6c485700bcb
# 15        NaN   VIC  4ee411945c5cfa48fa1fa0b3
# 16       3000   VIC  4b4005aaf964a5205fb425e3
# 17       3000   VIC  5b895204286fda002cad42bf
# 18        NaN   NaN  535b3da7498e1c1f30c7f617
# 19       3000   VIC  5bd680e52632ec002c350b5f
# 20       3000   VIC  5c7cd399180b910039710dca
# 21       3030   VIC  5c5142c9898bdc002ca1e708
# 22       3000   VIC  54990151498e4a0dda00303f
# 23        NaN   VIC  4bac048df964a52068de3ae3
# 24        NaN   VIC  4db3c1c493a017099dcbb2bd
# 25       3000   VIC  4dec6dc37d8b6c7a5371f5d4
# 26        NaN   NaN  534dbaef498e1cf349e09668
# 27        NaN   NaN  4b5d3fcaf964a520bb5729e3
# 28        NaN   VIC  4ddf8027b0fbefa198c605b5
# 29        NaN   NaN  4fa8e308e4b0bad895373a50

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
# for lat, lng, label in zip(dataframe_filtered['location.lat'], dataframe_filtered['location.lng'], dataframe_filter)
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d553709745b> in <module>
# ----> 1 venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel
#       2
#       3 # add a red circle marker to represent the Conrad Hotel
#       4 folium.features.CircleMarker(
#       5     [latitude, longitude],
#
# NameError: name 'folium' is not defined
